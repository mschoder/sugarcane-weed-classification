# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import numpy as np
import pathlib
import cv2
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
mask = cv2.imread('/Users/mschoder/Desktop/test_tile5_scribble_raw.png', cv2.IMREAD_GRAYSCALE)
plt.imshow(mask, cmap='Greys_r')
print(mask.shape)
# Out:
# (512, 512)

# %%
(thresh, im_bw) = cv2.threshold(mask, 128, 255, cv2.THRESH_BINARY)
# (thresh, im_bw) = cv2.threshold(im_gray, 128, 255, cv2.THRESH_OTSU)
plt.imshow(im_bw, cmap='Greys_r')
print(im_bw.shape)
# Out:
# (512, 512)

# %%
cv2.imwrite("/Users/mschoder/Desktop/test_tile5_scribble.png", im_bw)
# Out:
# True

# %%
m2 = cv2.imread("/Users/mschoder/Desktop/test_tile5_scribble.png", -1) # -1 flag for "unchanged" so not RBG
plt.imshow(m2, cmap='Greys_r')
print(m2.shape)
# Out:
# (512, 512)

# %%
orig = cv2.imread("/Users/mschoder/Desktop/test_tile5.jpg")
plt.figure()
plt.imshow(orig)
plt.imshow(m2, alpha=0.5, cmap='Greys_r')
