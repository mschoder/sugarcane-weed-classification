# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import numpy as np
import pathlib
import cv2
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
mask = cv2.imread('/Users/mschoder/Desktop/test_tile5_scribble_raw.png')
plt.imshow(mask)
print(mask.shape)
# Out:
# (512, 512, 3)

# %%
im_gray = cv2.imread('/Users/mschoder/Desktop/test_tile5_scribble.png', cv2.IMREAD_GRAYSCALE)
(thresh, im_bw) = cv2.threshold(im_gray, 128, 255, cv2.THRESH_BINARY)
# (thresh, im_bw) = cv2.threshold(im_gray, 128, 255, cv2.THRESH_OTSU)

# %%
plt.imshow(im_bw)

# %%
cv2.imwrite("/Users/mschoder/Desktop/test_tile5_scribble.png", im_bw)
# Out:
# True

# %%
m2 = cv2.imread("/Users/mschoder/Desktop/test_tile5_scribble.png")
plt.imshow(m2)

# %%
orig = cv2.imread("/Users/mschoder/Desktop/test_tile5.jpg")
plt.imshow(orig)
